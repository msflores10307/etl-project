# %%
import pandas as pd

# %%
path = "csvData.csv"
obesity_rates_df = pd.read_csv(path)
obesity_rates_df
# Out:
#               country  obesityRate      pop2020
# 0               Nauru         61.0       10.824
# 1        Cook Islands         55.9       17.564
# 2               Palau         55.3       18.094
# 3    Marshall Islands         52.9       59.190
# 4              Tuvalu         51.6       11.792
# ..                ...          ...          ...
# 187          Cambodia          3.9    16718.965
# 188             India          3.9  1380004.385
# 189       Timor-Leste          3.8     1318.445
# 190        Bangladesh          3.6   164689.383
# 191           Vietnam          2.1    97338.579
#
# [192 rows x 3 columns]

# %%
df = obesity_rates_df.rename(columns={"obesityRate":"Obesity Rate","country":"Country","pop2020":"Population"})
df
# Out:
#               Country  Obesity Rate   Population
# 0               Nauru          61.0       10.824
# 1        Cook Islands          55.9       17.564
# 2               Palau          55.3       18.094
# 3    Marshall Islands          52.9       59.190
# 4              Tuvalu          51.6       11.792
# ..                ...           ...          ...
# 187          Cambodia           3.9    16718.965
# 188             India           3.9  1380004.385
# 189       Timor-Leste           3.8     1318.445
# 190        Bangladesh           3.6   164689.383
# 191           Vietnam           2.1    97338.579
#
# [192 rows x 3 columns]

# %%
types = df.dtypes
print(types)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-7df65b3cd08b> in <module>
# ----> 1 df.astypes()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'astypes'
